# %%
##roll-based  login system

role1username = "Role 1"
role1password = "Role1pw"

role2username = "Role 2"
role2password = "Role2pw"

role3username = "Role3"
role3password = "Role3pw"

while True:
    print("========= Role Menu ============")
    print("1.Role 1")        #print("1.role 1 /n 2.role 2 /n 3.role3 /n Exit")
    print("2.Role 2")
    print("3.Role 3")
    print("Exit")
    print("=====================================")

    choice = int(input("Enter your choice (1-4):"))
    if choice == 1:
        print("You choosed Role1")

        attempts = 0
        while attempts<3:
            username1 = input("Enter your username:")
            password1 = input("Enter your password:")

            if username1 == role1username and password == role1password:
                print("Login Successful. Welcome to the system")
                break
        else:
            attempts +=1
            print("Invalid credentials /n Attempts Left:", 3-attempts)
        if attempts == 3:
            print("Too many attempts failed. Program Terminated")

    elif choice == 2:
        print("You choosed Role2")

        attempts = 0
        while attempts<3:
            username2 = input("Enter your username:")
            password2 = input("Enter your password:")

            if username2 == role2username and password3 == role2password:
                print("Login Successful. Welcome to the System.")
                break
            else:
                attempts += 1
                print("Invalid credentails /n Attempts left:", 3-attempts)
            if attempts == 3:
                print("Too many attempts failed. Program Terminated.")

        
           
           
    elif choice == 3:
        print("You choosed Role3")

        attempts = 0
        while attempts<3:
            username3 = input("Enter your username:")
            password3 = input("Enter your password:")

            if username3 == role3username and password3== role3password:
                print("Login Successful. Welcome to the system")
                break
            else:
                attempts +=1
                print("Invalid credentials /n Attempts Left:", 3-attempts)
            
            if attempts == 3:
                print("Too many attempts failed. Program Terminated")
    
    elif choice == 4:
        print("You have successfully log out.")
# Out:
# ========= Role Menu ============
# 1.Role 1
# 2.Role 2
# 3.Role 3
# Exit
# ...
# You choosed Role1
# Login Successful. Welcome to the system
# ========= Role Menu ============
# 1.Role 1
# 2.Role 2
# 3.Role 3
# Exit
# ...
# You have successfully log out.
# ========= Role Menu ============
# 1.Role 1
# 2.Role 2
# 3.Role 3
# Exit
# ...
# You choosed Role1

# %%
choice = [1,2,3]
def show_menu():
    choice1 = int(input("Enter your choice(1-3):"))
    if choice == 1:
        print("=====Boss Menu======")
        print("1. See Employee List")
        print("2. Check their Attendence.")
show_menu()

show_menu
# Out:
# <function __main__.show_menu()>

# %%
### practice question moodle
# 1.
length = 6
breadth = 3
Area_of_rectangle = length * breadth
print(Area_of_rectangle)
# Out:
# 18

# %%
# 2. Emplyee income tax

name = input("Enter your name please:")
monthly_income = int(input("Enter your monthly income:"))
numbers_of_kids = int(input("Enter number of kids you have:"))
tax = 0.25 * (monthly_income *11 - numbers_of_kids * 450)
print(f"Employee name: {name}")
print(f"Your yearly taxable amount is: {tax} rupees")
# Out:
# Employee name: Anish
# Your yearly taxable amount is: 82275.0 rupees

# %%
# 3. get integer, add 5, double it, subtract 7 and display

integer = int(input("Enter an integer:"))
print(f"You entered: {integer}")
integer += 5

print(f"After adding 5, integer becomes: {integer}")

print(f"Doubling the number: {integer * integer}")
print(f"After subtracting 7 from it, the number become: {integer-7}")
# Out:
# You enterd: 2
# After adding 5, integer becomes: 7
# Doubling the number: 49
# After subtracting 7 from it, the number become: 0

# %%
## get radius and calculate area and circumference

radius = float(input("Enter radius of circle:"))
print(f"Radius of circle is: {radius}")

# %%
delayed_day = int(input("Enter number of days:"))
print(f"Enter the Number of days: {delayed_day}")

if delayed_day == 0:
    print("N0 fine.")
elif delayed_day > 0 and delayed_day <=5:
    fine = delayed_day * 0.3
    print("Fine Amount Pay to RM:", fine)
elif delayed_day > 5 and delayed_day <=10:
    fine = (5 * 0.3) + ((delayed_day - 5) * 1)
    print("Fine Amount Pay to RM:", fine)
elif delayed_day > 10 and delayed_day <= 30:
    fine = (5 * 0.3) + (5 * 1) + ((delayed_day - 10) * 5)
    print("Fine Amount Pay to RM:", fine)
else:
    print("Your membership is cancelled since you returned book after 30 days.")
